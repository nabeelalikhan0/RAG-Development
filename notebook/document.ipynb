# %% [markdown]
# ## Data ingestion

# %%
## Document Structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the main text content i am using to create RAG",
    metadata = {
        "source":"example.txt",
        "pages":1,
        "author":"Nabeel Ali Khan",
        "date_created":"2026-06-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Nabeel Ali Khan', 'date_created': '2026-06-01'}, page_content='This is the main text content i am using to create RAG')

# %%
import os 
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt": """Python is a high-level programming language
      known for its simple and readable syntax. It has the following features:

Allows writing clean code with fewer lines.
Supports multiple programming paradigms including object-oriented, functional and procedural programming.
Widely used in web development, automation, data analysis, artificial intelligence and many other fields.
Dynamically typed and has automatic garbage collection
Hello World Program
The Hello World program demonstrates the basic structure of a Python program.




# This is a comment. It will not be executed.
print("Hello, World!")

Output
Hello, World!
How does this work:




hello_world
Hellow World Program
print() is a built-in Python function that instructs the computer to display text on the screen.
"Hello, World!" is a string enclosed within quotes (either single ' or double ").
Python uses indentation (spaces or tabs) to define code blocks instead of braces {} in C, C++ and Java .
# is used to write comments in Python. Comments are ignored during execution.
Related Articles:""",

"../data/text_files/machine_learning_intro.txt":"""Machine learning
 is a subset of artificial intelligence where computers learn from data and 
 identify patterns to make decisions or predictions without being explicitly programmed. Instead of writing rigid, step-by-step instructions, developers feed algorithms large datasets, allowing the system to "learn" the rules automatically.
 How it WorksTraditional programming requires you to input explicit rules and data into a computer to get an answer. Machine learning flips this approach: you feed the computer data and the corresponding answers, and the computer figures out the rules.
 Data Input: High-quality historical data (like past emails, medical records, or user preferences) is collected and prepared.
 Algorithms: Mathematical models (like neural networks or decision trees) process this data to find hidden trends.
 Training: The model iteratively adjusts itself to minimize errors until it can accurately predict outcomes on new, unseen data.
 Core CategoriesMachine learning is broadly divided into three main branches based on how the machine "learns" from the data:"""

}

for file_path,content in sample_texts.items():
    with open(file_path,"w",encoding="utf-8") as f:
        f.write(content)
        print("File Created",file_path)
# Out:
# File Created ../data/text_files/python_intro.txt
# File Created ../data/text_files/machine_learning_intro.txt

# %%
## Text Loader

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
loader.encoding,loader
# Out:
# C:\Users\nabee\AppData\Local\Temp\ipykernel_40848\3918360426.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# ('utf-8',
#  <langchain_community.document_loaders.text.TextLoader at 0x1fc220c06e0>)

# %%
document = loader.load()
document
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a high-level programming language\n      known for its simple and readable syntax. It has the following features:\n\nAllows writing clean code with fewer lines.\nSupports multiple programming paradigms including object-oriented, functional and procedural programming.\nWidely used in web development, automation, data analysis, artificial intelligence and many other fields.\nDynamically typed and has automatic garbage collection\nHello World Program\nThe Hello World program demonstrates the basic structure of a Python program.\n\n\n\n\n# This is a comment. It will not be executed.\nprint("Hello, World!")\n\nOutput\nHello, World!\nHow does this work:\n\n\n\n\nhello_world\nHellow World Program\nprint() is a built-in Python function that instructs the computer to display text on the screen.\n"Hello, World!" is a string enclosed within quotes (either single \' or double ").\nPython uses indentatio
# ...

# %%
## Directory loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files/",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"},
)

dir_loader.load()
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning_intro.txt'}, page_content='Machine learning\n is a subset of artificial intelligence where computers learn from data and \n identify patterns to make decisions or predictions without being explicitly programmed. Instead of writing rigid, step-by-step instructions, developers feed algorithms large datasets, allowing the system to "learn" the rules automatically.\n How it WorksTraditional programming requires you to input explicit rules and data into a computer to get an answer. Machine learning flips this approach: you feed the computer data and the corresponding answers, and the computer figures out the rules.\n Data Input: High-quality historical data (like past emails, medical records, or user preferences) is collected and prepared.\n Algorithms: Mathematical models (like neural networks or decision trees) process this data to find hidden trends.\n Training: The model iteratively adjusts itself to minimize errors
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf_files/",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
)

dir_loader.load()
# Out:
# Error loading file ..\data\pdf_files\English_Teacher_AI_Prompts.pdf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       6     loader_cls=PyMuPDFLoader,
#       7     loader_kwargs={"encoding":"utf-8"},
#       8 )
#       9
# ---> 10 dir_loader.load()
#
# File d:\Test\Python\RAG\.venv\Lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File d:\Test\Python\RAG\.venv\Lib\site-packages\langchain_community\document_loaders\directory.py:195, in DirectoryLoader.lazy_load(self)
#     193 else:
#     194     for i in items:
# --> 195         yield from self._lazy_load_file(i, p, pbar)
#     197 if pbar:
#     198     pbar.close()
#
# ...
